# %%
import pandas as pd
import numpy as np
import os 
import seaborn as sns
import graphviz

# %%
df = pd.read_csv('..\documents\generated\df_inicial_3%.csv', low_memory=False)
display(df)
# Out:
#         subject_id charttime_chartevent value_chartevent  valuenum_chartevent  \
# 0         10036156  2157-07-02 04:00:00               92                 92.0
# 1         10011398  2146-12-16 05:00:00            Sharp                  NaN
# 2         10018845  2184-10-08 04:38:00  Normal for Race                  NaN
# 3         10018081  2133-12-19 12:26:00             Swab                  NaN
# 4         10018081  2133-12-19 06:00:00       2 rails up                  NaN
# ...            ...                  ...              ...                  ...
# 358190    10019003  2153-03-28 19:00:00               97                 97.0
# 358191    10023117  2175-07-07 00:00:00          Regular                  NaN
# 358192    10023117  2175-03-21 16:00:00   Obeys Commands                  6.0
# 358193    10023117  2175-03-21 07:17:00               35                 35.0
# 358194    10019003  2155-07-10 23:01:00               57                 57.0
#
#        valueuom_chartevent                         label_chartevent  \
# 0                        %  O2 Saturation Pulseoxymetry Alarm - Low
# 1                  Unknown                                Pain Type
# 2                  Unknown                               Skin Color
# 3                  Unknown                                Oral Care
# 4                  Unknown                              Side  Rails
# ...                    ...                                      ...
# 358190                   %              O2 saturation pulseoxymetry
# 358191             Unknown                 Breathing pattern/effort
# 358192             Unknown                     GCS - Motor Response
# 358193                mmHg   Pulmonary Artery Pressure Alarm - High
# 358194                mmHg    Non Invasive Blood Pressure diastolic
#
#                          category  time_since_admission_chartevent icd_code  \
# 0                          Alarms                        23.133333     2724
# 1                   Pain/Sedation                        21.750000     2724
# 2               Skin - Assessment                         2.166667     2724
# 3                      Treatments                        19.466667     2724
# 4       Restraint/Support Systems                        13.033333     2724
# ...                           ...                              ...      ...
# 358190                Respiratory                        19.583333   Z87891
# 358191                  Pulmonary                         8.050000   Z87891
# 358192               Neurological                        16.516667   Z87891
# 358193                     Alarms                         7.800000   Z87891
# 358194        Routine Vital Signs                         5.216667   Z87891
#
#                      admission_type  ...                race  \
# 0                            URGENT  ...             UNKNOWN
# 1       SURGICAL SAME DAY ADMISSION  ...  HISPANIC OR LATINO
# 2                          EW EMER.  ...               WHITE
# 3                          EW EMER.  ...               WHITE
# 4                          EW EMER.  ...               WHITE
# ...                             ...  ...                 ...
# 358190                     EW EMER.  ...               WHITE
# 358191            OBSERVATION ADMIT  ...               WHITE
# 358192            OBSERVATION ADMIT  ...               WHITE
# 358193            OBSERVATION ADMIT  ...               WHITE
# 358194                     EW EMER.  ...               WHITE
#
#             admission_location age   charttime_labevent value_labevent  \
# 0       TRANSFER FROM HOSPITAL  88  2157-07-02 04:07:00             12
# 1           PHYSICIAN REFERRAL  67  2146-12-16 02:21:00            3.2
# 2               EMERGENCY ROOM  91  2184-10-08 20:37:00            NaN
# 3               EMERGENCY ROOM  79  2133-12-18 17:28:00            5.1
# 4               EMERGENCY ROOM  79  2133-12-18 17:28:00           13.9
# ...                        ...  ..                  ...            ...
# 358190          EMERGENCY ROOM  70  2153-03-28 14:04:00             30
# 358191          EMERGENCY ROOM  58  2175-07-06 18:37:00            1.9
# 358192  TRANSFER FROM HOSPITAL  58  2175-03-21 09:03:00            NaN
# 358193  TRANSFER FROM HOSPITAL  58  2175-03-21 09:03:00            NaN
# 358194  TRANSFER FROM HOSPITAL  72  2155-07-10 23:48:00            ___
#
#        valuenum_labevent  valueuom_labevent priority            admittime  \
# 0                   12.0              mEq/L  ROUTINE  2157-07-01 04:52:00
# 1                    3.2              mg/dL     STAT  2146-12-15 07:15:00
# 2                    NaN            Unknown     STAT  2184-10-08 02:28:00
# 3                    5.1              mg/dL  ROUTINE  2133-12-18 16:58:00
# 4                   13.9                  %  ROUTINE  2133-12-18 16:58:00
# ...                  ...                ...      ...                  ...
# 358190              30.0              mg/dL  ROUTINE  2153-03-27 23:25:00
# 358191               1.9              mg/dL     STAT  2175-07-06 15:57:00
# 358192               NaN              mg/dL  ROUTINE  2175-03-20 23:29:00
# 358193               NaN            Unknown  ROUTINE  2175-03-20 23:29:00
# 358194               0.5              mg/dL     STAT  2155-07-10 17:48:00
#
#        time_since_admission_labevent
# 0                          23.250000
# 1                          19.100000
# 2                          18.150000
# 3                           0.500000
# 4                           0.500000
# ...                              ...
# 358190                     14.650000
# 358191                      2.666667
# 358192                      9.566667
# 358193                      9.566667
# 358194                      6.000000
#
# [358195 rows x 21 columns]

# %%
# drop of tables
df = df.drop(columns=['charttime_chartevent', 'charttime_labevent', 'admittime'])

# %%
df_filtered = df[df[['valuenum_chartevent', 'valuenum_labevent', 'valueuom_labevent']].notna().all(axis=1)]

# %%
min_count = df_filtered['icd_code'].value_counts().min()
print(min_count)
# Out:
# 8209

# %%
# 6200 for every sigle icd_code (6)
min_count = 8209

df_sample = df_filtered.groupby('icd_code', group_keys=False).sample(n=min_count, random_state=42)
display(df_sample)
# Out:
#         subject_id value_chartevent  valuenum_chartevent valueuom_chartevent  \
# 39375     10014078              103                103.0                  °F
# 17063     10011398               25                 25.0               mEq/L
# 60766     10011398               25                 25.0                  mA
# 12851     10011398             36.8                 36.8                  °C
# 42526     10023771              100                100.0                   %
# ...            ...              ...                  ...                 ...
# 332992    10023117              104                104.0               mg/dL
# 338698    10019003   Obeys Commands                  6.0             Unknown
# 336645    10023117      No response                  1.0             Unknown
# 314266    10037861      No movement                  0.0             Unknown
# 314052    10015860                8                  8.0            insp/min
#
#                              label_chartevent                     category  \
# 39375                  Temperature Fahrenheit          Routine Vital Signs
# 17063                    TCO2 (calc) Arterial                         Labs
# 60766   Temporary Ventricular Stim Setting mA  Cardiovascular (Pacer Data)
# 12851                     Temperature Celsius          Routine Vital Signs
# 42526             O2 saturation pulseoxymetry                  Respiratory
# ...                                       ...                          ...
# 332992                        Glucose (serum)                         Labs
# 338698                   GCS - Motor Response                 Neurological
# 336645                   GCS - Motor Response                 Neurological
# 314266                         Strength L Arm                 Neurological
# 314052                       Resp Alarm - Low                       Alarms
#
#         time_since_admission_chartevent icd_code               admission_type  \
# 39375                          4.850000     2724                     EW EMER.
# 17063                          7.900000     2724  SURGICAL SAME DAY ADMISSION
# 60766                         16.750000     2724  SURGICAL SAME DAY ADMISSION
# 12851                         18.750000     2724  SURGICAL SAME DAY ADMISSION
# 42526                         22.750000     2724                     ELECTIVE
# ...                                 ...      ...                          ...
# 332992                         9.050000   Z87891            OBSERVATION ADMIT
# 338698                         1.600000   Z87891                     EW EMER.
# 336645                         4.950000   Z87891            OBSERVATION ADMIT
# 314266                        23.433333   Z87891                     EW EMER.
# 314052                        12.550000   Z87891                     EW EMER.
#
#        insurance                race      admission_location  age  \
# 39375   Medicaid    UNABLE TO OBTAIN          EMERGENCY ROOM   60
# 17063      Other  HISPANIC OR LATINO      PHYSICIAN REFERRAL   67
# 60766      Other  HISPANIC OR LATINO      PHYSICIAN REFERRAL   67
# 12851      Other  HISPANIC OR LATINO      PHYSICIAN REFERRAL   67
# 42526   Medicare               WHITE      PHYSICIAN REFERRAL   70
# ...          ...                 ...                     ...  ...
# 332992  Medicare               WHITE          EMERGENCY ROOM   58
# 338698     Other               WHITE  TRANSFER FROM HOSPITAL   72
# 336645  Medicare               WHITE  TRANSFER FROM HOSPITAL   58
# 314266  Medicare             UNKNOWN          EMERGENCY ROOM   79
# 314052     Other               WHITE      PHYSICIAN REFERRAL   59
#
#        value_labevent  valuenum_labevent valueuom_labevent priority  \
# 39375              -3               -3.0             mEq/L  Unknown
# 17063             1.4                1.4           Unknown     STAT
# 60766             384              384.0             mm Hg  Unknown
# 12851              98               98.0                 %  Unknown
# 42526             1.2                1.2           Unknown  ROUTINE
# ...               ...                ...               ...      ...
# 332992              2                2.0           Unknown     STAT
# 338698            1.1                1.1             mg/dL     STAT
# 336645            ___              133.0             mEq/L     STAT
# 314266             21               21.0             mg/dL     STAT
# 314052            8.9                8.9              g/dL     STAT
#
#         time_since_admission_labevent
# 39375                       12.316667
# 17063                        4.150000
# 60766                        5.616667
# 12851                        6.666667
# 42526                       15.366667
# ...                               ...
# 332992                       2.666667
# 338698                       6.000000
# 336645                       2.566667
# 314266                       9.183333
# 314052                     -14.950000
#
# [49254 rows x 18 columns]

# %%
missing = df_sample.isnull().sum()
missing_percent = (missing / len(df_sample)) * 100
print(pd.DataFrame({"Missing": missing, "Percent (%)": missing_percent}))

sns.heatmap(df_sample.isnull(), cbar=False)
# Out:
#                                  Missing  Percent (%)
# subject_id                             0          0.0
# value_chartevent                       0          0.0
# valuenum_chartevent                    0          0.0
# valueuom_chartevent                    0          0.0
# label_chartevent                       0          0.0
# category                               0          0.0
# time_since_admission_chartevent        0          0.0
# icd_code                               0          0.0
# admission_type                         0          0.0
# insurance                              0          0.0
# race                                   0          0.0
# admission_location                     0          0.0
# age                                    0          0.0
# value_labevent                         0          0.0
# valuenum_labevent                      0          0.0
# valueuom_labevent                      0          0.0
# priority                               0          0.0
# time_since_admission_labevent          0          0.0
# <Axes: >

# %%
df_sample.to_csv("df_balanced_full.csv", index=False)
