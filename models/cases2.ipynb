# %%
import pandas as pd

# %%
cases = pd.DataFrame([
    {
        'value_chart': 'Full resistance',
        'valuenum_chartevent': 5.0,
        'chart_label': 'Strength L Arm',
        'category': 'Neurological',
        'time_since_admission_chartevent': 13.116667,
        'admission_type': 'SURGICAL SAME DAY ADMISSION',
        'race': 'OTHER',
        'age': 66,
        'lab_results': 138.0,
        'lab_value_unit':'mg/dL',
        'priority': 'Unknown',
        'time_since_admission_labevent': 1.900000,
        'death': 0,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)': 71.00,
        'Weight (Lbs)': 0.0
    },
    {
        'value_chart': 'No movement',
        'valuenum_chartevent': 103.0,
        'chart_label': 'O2 saturation pulseoxymetry',
        'category': 'Routine Vital Signs',
        'time_since_admission_chartevent': 12.0000,
        'admission_type': 'URGENT',
        'race': 'WHITE',
        'age': 72,
        'lab_results': 24.0,
        'lab_value_unit': 'mEq/L',
        'priority': 'STAT',
        'time_since_admission_labevent': 1.22500,
        'death': 0,
        'BMI (kg/m2)': 25.8,
        'Height (Inches)': 67.63,
        'Weight (Lbs)': 165.00
    },
    {
        'value_chart': '22',
        'valuenum_chartevent': -5.0,
        'chart_label': 'Richmond-RAS Scale',
        'category': 'Pain/Sedation',
        'time_since_admission_chartevent': 10.65000,
        'admission_type': 'OBSERVATION ADMIT',
        'race': 'WHITE',
        'age': 48,
        'lab_results': 40,
        'lab_value_unit': 'sec',
        'priority': 'ROUTINE',
        'time_since_admission_labevent': 5.96400,
        'death': 0,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)': 0.0,
        'Weight (Lbs)': 0.0
    },
    {
        'value_chart': '74',
        'valuenum_chartevent': 74.0,
        'chart_label': 'Non Invasive Blood Pressure mean',
        'category': 'Routine Vital Signs',
        'time_since_admission_chartevent': 14.450000,
        'admission_type': 'EW EMER.',
        'race': 'WHITE',
        'age': 89,
        'lab_results':11.9,
        'lab_value_unit':'sec',
        'priority': 'ROUTINE',
        'time_since_admission_labevent': 10.083333,
        'death': 0,
        'BMI (kg/m2)': 26.0,
        'Height (Inches)': 66.00,
        'Weight (Lbs)': 161.16
    },
    {
        'value_chart': 'Bedfast',
        'valuenum_chartevent': 5.0,
        'chart_label': 'Braden Activity',
        'category': 'Skin - Assessment',
        'time_since_admission_chartevent': 8.86000,
        'admission_type': 'URGENT',
        'race': 'HISPANIC OR LATINO',
        'age': 67,
        'lab_results': 4.6,
        'lab_value_unit':'mEq/L',
        'priority': 'STAT',
        'time_since_admission_labevent': 3.866666,
        'death':0,
        'BMI (kg/m2)':0.0,
        'Height (Inches)': 0.0,
        'Weight (Lbs)': 135.0,
    },
    {
        'value_chart': '26',
        'valuenum_chartevent': 26,
        'chart_label': 'Unknown',
        'category': 'Labs',
        'time_since_admission_chartevent': 3.333333,
        'admission_type': 'SURGICAL SAME DAY ADMISSION',
        'race': 'OTHER',
        'age': 70,
        'lab_results': 4.45,
        'lab_value_unit':'m/uL',
        'priority': 'STAT',
        'time_since_admission_labevent': 5.70000,
        'death':1,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)':0.0,
        'Weight (Lbs)':0.0,
    }
])

# %%
cases.to_csv("cases2.csv", index=False)

# %%
df = pd.read_csv("cases2.csv")
display(df)
# Out:
#        value_chart  valuenum_chartevent                       chart_label  \
# 0  Full resistance                  5.0                    Strength L Arm
# 1      No movement                103.0       O2 saturation pulseoxymetry
# 2               22                 -5.0                Richmond-RAS Scale
# 3               74                 74.0  Non Invasive Blood Pressure mean
# 4          Bedfast                  5.0                   Braden Activity
# 5               26                 26.0                           Unknown
#
#               category  time_since_admission_chartevent  \
# 0         Neurological                        13.116667
# 1  Routine Vital Signs                        12.000000
# 2        Pain/Sedation                        10.650000
# 3  Routine Vital Signs                        14.450000
# 4    Skin - Assessment                         8.860000
# 5                 Labs                         3.333333
#
# ...
