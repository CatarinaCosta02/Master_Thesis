# %%
import pandas as pd

# %%
cases = pd.DataFrame([
    #este
    {
        'value_chart': '65',
        'valuenum_chartevent': 65.0,
        'chart_label': 'Heart Rate',
        'category': 'Routine Vital Signs',
        'time_since_admission_chartevent': 10.21667,
        'admission_type': 'EW EMER.',
        'race': 'WHITE',
        'age': 87,
        'lab_results': 12.40,
        'lab_value_unit':'K/uL',
        'priority': 'STAT',
        'time_since_admission_labevent': 4.933333,
        'death': 0,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)': 0.00,
        'Weight (Lbs)': 0.0
    },
    {
        'value_chart': 'No movement',
        'valuenum_chartevent': 103.0,
        'chart_label': 'O2 saturation pulseoxymetry',
        'category': 'Routine Vital Signs',
        'time_since_admission_chartevent': 12.0000,
        'admission_type': 'URGENT',
        'race': 'WHITE',
        'age': 72,
        'lab_results': 24.0,
        'lab_value_unit': 'mEq/L',
        'priority': 'STAT',
        'time_since_admission_labevent': 1.22500,
        'death': 0,
        'BMI (kg/m2)': 25.8,
        'Height (Inches)': 67.63,
        'Weight (Lbs)': 165.00
    },
    {
        'value_chart': '22',
        'valuenum_chartevent': -5.0,
        'chart_label': 'Richmond-RAS Scale',
        'category': 'Pain/Sedation',
        'time_since_admission_chartevent': 10.65000,
        'admission_type': 'OBSERVATION ADMIT',
        'race': 'WHITE',
        'age': 48,
        'lab_results': 40,
        'lab_value_unit': 'sec',
        'priority': 'ROUTINE',
        'time_since_admission_labevent': 5.96400,
        'death': 0,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)': 0.0,
        'Weight (Lbs)': 0.0
    },
    # este
    {
        'value_chart': '4 - Chair - Transfer to chair/bed',
        'valuenum_chartevent': 4.0,
        'chart_label': 'Activity / Mobility (JH-HLM)',
        'category': 'Treatments',
        'time_since_admission_chartevent': 9.900000,
        'admission_type': 'EW EMER.',
        'race': 'WHITE',
        'age': 32,
        'lab_results':7.80,
        'lab_value_unit':'mg/dL',
        'priority': 'ROUTINE',
        'time_since_admission_labevent': 17.400000,
        'death': 0,
        'BMI (kg/m2)': 25.1,
        'Height (Inches)': 65.00,
        'Weight (Lbs)': 152.0
    },
    {
        'value_chart': 'Bedfast',
        'valuenum_chartevent': 5.0,
        'chart_label': 'Braden Activity',
        'category': 'Skin - Assessment',
        'time_since_admission_chartevent': 8.86000,
        'admission_type': 'URGENT',
        'race': 'HISPANIC OR LATINO',
        'age': 67,
        'lab_results': 4.6,
        'lab_value_unit':'mEq/L',
        'priority': 'STAT',
        'time_since_admission_labevent': 3.866666,
        'death':0,
        'BMI (kg/m2)':0.0,
        'Height (Inches)': 0.0,
        'Weight (Lbs)': 135.0,
    },
    {
        'value_chart': '26',
        'valuenum_chartevent': 26,
        'chart_label': 'Unknown',
        'category': 'Labs',
        'time_since_admission_chartevent': 3.333333,
        'admission_type': 'SURGICAL SAME DAY ADMISSION',
        'race': 'OTHER',
        'age': 70,
        'lab_results': 4.45,
        'lab_value_unit':'m/uL',
        'priority': 'STAT',
        'time_since_admission_labevent': 5.70000,
        'death':1,
        'BMI (kg/m2)': 0.0,
        'Height (Inches)':0.0,
        'Weight (Lbs)':0.0,
    }
])

# %%
cases.to_csv("cases2.csv", index=False)

# %%
df = pd.read_csv("cases2.csv")
display(df)
# Out:
#                          value_chart  valuenum_chartevent  \
# 0                                 65                 65.0
# 1                        No movement                103.0
# 2                                 22                 -5.0
# 3  4 - Chair - Transfer to chair/bed                  4.0
# 4                            Bedfast                  5.0
# 5                                 26                 26.0
#
#                     chart_label             category  \
# 0                    Heart Rate  Routine Vital Signs
# 1   O2 saturation pulseoxymetry  Routine Vital Signs
# 2            Richmond-RAS Scale        Pain/Sedation
# 3  Activity / Mobility (JH-HLM)           Treatments
# 4               Braden Activity    Skin - Assessment
# 5                       Unknown                 Labs
#
#    time_since_admission_chartevent               admission_type  \
# 0                        10.216670                     EW EMER.
# 1                        12.000000                       URGENT
# 2                        10.650000            OBSERVATION ADMIT
# 3                         9.900000                     EW EMER.
# 4                         8.860000                       URGENT
# 5                         3.333333  SURGICAL SAME DAY ADMISSION
#
#                  race  age  lab_results lab_value_unit priority  \
# 0               WHITE   87        12.40           K/uL     STAT
# 1               WHITE   72        24.00          mEq/L     STAT
# 2               WHITE   48        40.00            sec  ROUTINE
# 3               WHITE   32         7.80          mg/dL  ROUTINE
# 4  HISPANIC OR LATINO   67         4.60          mEq/L     STAT
# 5               OTHER   70         4.45           m/uL     STAT
#
#    time_since_admission_labevent  death  BMI (kg/m2)  Height (Inches)  \
# 0                       4.933333      0          0.0             0.00
# 1                       1.225000      0         25.8            67.63
# 2                       5.964000      0          0.0             0.00
# 3                      17.400000      0         25.1            65.00
# 4                       3.866666      0          0.0             0.00
# 5                       5.700000      1          0.0             0.00
#
#    Weight (Lbs)
# 0           0.0
# 1         165.0
# 2           0.0
# 3         152.0
# 4         135.0
# 5           0.0
